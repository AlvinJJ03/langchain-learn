# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

client = OpenAI(
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="qwen-plus",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False
)

print(response.model_dump_json())
print(response.choices[0].message.content)
# Out:
# 🚀 正在调用大模型...
# ChatCompletion(id='chatcmpl-eaf90b59-72c3-9974-9764-5115bdd56ece', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='你好呀！😊 我是通义千问（Qwen），阿里巴巴集团旗下的超大规模语言模型。你可以叫我Qwen，或者亲切地叫我小Q～  \n我擅长回答问题、解答疑惑、写故事、写公文、写邮件、写剧本、逻辑推理、编程，还能表达观点，甚至陪你聊天、玩游戏！虽然我是AI，但我会尽力用温暖、耐心和清晰的方式和你交流。\n\n如果你有任何问题、需要帮助，或者只是想聊聊天、分享心情——我都在这里，很乐意陪你一起探索、思考或放松 🌟  \n那么，今天有什么想聊的，或者需要我帮忙的吗？😄', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1776754706, model='qwen-plus', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=139, prompt_tokens=26, total_tokens=165, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=0)))
